# %%
# example adapted from
# https://matplotlib.org/stable/gallery/images_contours_and_fields/plot_streamplot.html
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")
from utils import *

# %% [markdown]
# Observation for Andronov-Hopf, we see that when alpha:
# - is negative: the chosen orbits go towards the center
# - is equal to 0: the points perform almost circular orbits
# - is positive: are repelled by the center

# %%
#Set the margins of the plot
w = 4
#Set the density of the mesh (we have gotten similar values for the phase plots to those from thh internet
# only when we used a large desnity
density = 3
#Create the mesh
Y, X = np.mgrid[-w:w:100j, -w:w:100j]

#Generate 3 different phase diagrams
for alpha in [-1, 0, 1]:
    andronov_hopf(alpha, X, Y, w, density)

# %%
from utils import cusp
#The boundaries of the plotted area
w = 1
#The number of points per coordinate (for my system there is a good speed-visualization
#trade-off between 20 and 40)
count = 20

cusp(w, count)
