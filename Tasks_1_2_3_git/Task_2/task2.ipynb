# %%
# example adapted from
# https://matplotlib.org/stable/gallery/images_contours_and_fields/plot_streamplot.html
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")
from utils import *

# %%
alphas = np.linspace(-2, 12, 100)

# %% [markdown]
# Plot the bifurcation for the first speed

# %%
plot_bifurcation(alphas, 1)
plt.show()

# %% [markdown]
# Plot the bifurcation for the second speed

# %%
plot_bifurcation(alphas, 2)
plt.show()
